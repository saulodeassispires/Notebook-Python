# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.expected_conditions import ( presence_of_element_located )

# %%
# set webbrowser working on backgound 
#Options = Options()
#Options.headless = True

# create webdriver object
#driver = webdriver.Chrome(options=Options)

url = 'https://www.facebook.com/ads/library/?active_status=all&ad_type=all&country=US&q=ramseysolutions.com&sort_data[direction]=desc&sort_data[mode]=relevancy_monthly_grouped&search_type=keyword_unordered&media_type=all'
url = 'https://www.facebook.com/ads/library/?active_status=all&ad_type=all&country=US&q=newscientist.com&sort_data[direction]=desc&sort_data[mode]=relevancy_monthly_grouped&search_type=keyword_unordered&media_type=all'

driver = webdriver.Chrome()

driver.get(url)

wdw = WebDriverWait(driver,60)

locator = (By.XPATH, '/html/body/div[1]/div[1]/div[1]/div/div/div/div[5]/div[1]/div/div/div/div/div/div[1]/div')
wdw.until(presence_of_element_located(locator))
texto = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div/div/div/div[5]/div[1]/div/div/div/div/div/div[1]/div').text



print(texto)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       8 url = 'https://www.facebook.com/ads/library/?active_status=all&ad_type=all&country=US&q=ramseysolutions.com&sort_data[direction]=desc&sort_data[mode]=relevancy_monthly_grouped&search_type=keyword_unordered&media_type=all'
#       9 url = 'https://www.facebook.com/ads/library/?active_status=all&ad_type=all&country=US&q=newscientist.com&sort_data[direction]=desc&sort_data[mode]=relevancy_monthly_grouped&search_type=keyword_unordered&media_type=all'
# ---> 11 driver = webdriver.Chrome()
#      13 driver.get(url)
#      15 wdw = WebDriverWait(driver,60)
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.expected_conditions import ( presence_of_element_located )

# set webbrowser working on backgound 
Options = Options()
Options.headless = True

# create webdriver object
driver = webdriver.Chrome(options=Options)

# open list website to be checked 
#websites_to_be_checked = open("c:/Saulo/to_be_checked.txt", "a", encoding="UTF-8")
websites_validated = open("c:/Saulo/website_validated.txt", "w", encoding="UTF-8")

contador = 0 

with open("c:/Saulo/to_be_checked.txt") as websites_to_be_checked:
    for site in websites_to_be_checked:

        driver.get(site)
        
        # wait for paging totally opened
        #time.sleep(3)
        wdw = WebDriverWait(driver,60)
        locator = (By.XPATH, '/html/body/div[1]/div[1]/div[1]/div/div/div/div[5]/div[1]/div/div/div/div/div/div[1]/div')
        wdw.until(presence_of_element_located(locator))
        
        # extracts the element
        texto = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div/div/div/div[5]/div[1]/div/div/div/div/div/div[1]/div').text

        if texto == "0 resultados":
            resultado = 'bad'
        else: 
            resultado = 'ok'   
        
        registro = site.rstrip() + ';' + resultado + "\n"
        websites_validated.write(registro)

        contador = contador + 1

        print(f'{contador} ' + site)

#close files 
websites_to_be_checked.close()
websites_validated.close()
# Out:
# 1 https://www.facebook.com/ads/library/?active_status=all&ad_type=all&country=US&q=ramseysolutions.com&sort_data[direction]=desc&sort_data[mode]=relevancy_monthly_grouped&search_type=keyword_unordered&media_type=all
#
# 2 https://www.facebook.com/ads/library/?active_status=all&ad_type=all&country=US&q=newscientist.com&sort_data[direction]=desc&sort_data[mode]=relevancy_monthly_grouped&search_type=keyword_unordered&media_type=all
#
# 3 https://www.facebook.com/ads/library/?active_status=all&ad_type=all&country=US&q=lifehack.org&sort_data[direction]=desc&sort_data[mode]=relevancy_monthly_grouped&search_type=keyword_unordered&media_type=all
#
# 4 https://www.facebook.com/ads/library/?active_status=all&ad_type=all&country=US&q=fullscript.com&sort_data[direction]=desc&sort_data[mode]=relevancy_monthly_grouped&search_type=keyword_unordered&media_type=all
#
# ...
