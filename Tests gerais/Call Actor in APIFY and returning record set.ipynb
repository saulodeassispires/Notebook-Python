# %%
from apify_client import ApifyClient

apify_client = ApifyClient('apify_api_g1rFyGYaBEHIuLudGEWgFZw3fxW3bp2B4H7B')

# Collection clients do not require a parameter
actor_collection_client = apify_client.actors()

# List all of your actors
#actor_list = actor_collection_client.list().items
#print(actor_list)

# Start an task and waits for it to finish
#actor_call = apify_client.task('saulo_pires/facebook-page-ads-task-2').call()

actor_call = apify_client.task('saulo_pires/myfifthactor-task-1').call()

# Start an actor and waits for it to finish
#actor_call = apify_client.actor('saulo_pires~myfifthactor').call()

# Fetch results from the actor's default dataset
dataset_items = apify_client.dataset(actor_call['defaultDatasetId']).list_items().items

print(dataset_items)
# Out:
# [{'_value': 'html', 'html': [{'_attributes': {'lang': 'pt-BR', 'data-range': 'xlarge'}, 'head': [{'title': [{'_value': 'Terra - Notícias, esportes, coberturas ao vivo, diversão e estilo de vida'}], 'meta': [{'_attributes': {'http-equiv': 'X-UA-Compatible', 'content': 'IE=Edge'}}, {'_attributes': {'charset': 'utf-8'}}, {'_attributes': {'name': 'description', 'content': 'Veja no Terra as últimas notícias e as melhores coberturas ao vivo do Brasil e do Mundo, Esportes, Diversão, Vida e Estilo e assista os melhores vídeos no TerraTV.'}}, {'_attributes': {'name': 'keywords', 'content': ''}}, {'_attributes': {'http-equiv': 'default-style', 'content': 'text/css'}}, {'_attributes': {'name': 'viewport', 'content': 'width=device-width, initial-scale=1.0'}}, {'_attributes': {'name': 'theme-color', 'content': '#ff7212'}}, {'_attributes': {'name': 'referrer', 'content': 'origin'}}, {'_attributes': {'http-equiv': 'Content-Security-Policy', 'content': 'block-all-mixed-content'}}, {'_attributes': {'
# ...
