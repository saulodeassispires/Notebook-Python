# %%
class Gato:

    # aqui é classe do gato 
    def __init__(self, nome):
        # aqui inicializa a primeira parte do codigo 
        self.tipo_animal = 'Felino'
        self.nome = nome
        print('Um gato é um animal', self.tipo_animal, ' ', self.nome)
    
    @classmethod
    def imprimir(cls,nome) -> str:
        print(nome, ' Timao campeao ' )
        

nome_do_gato = input('Digite o nome de seu gato: ')

gato1 = Gato.imprimir(nome_do_gato)
# Out:
# a  Timao campeao

# %%
class Gato:

    # aqui é classe do gato 
    def __init__(self, nome):
        # aqui inicializa a primeira parte do codigo 
        self.tipo_animal = 'Felino'
        self.nome = nome
        print('Um gato é um animal', self.tipo_animal, ' ', self.nome)

# %%
import requests 
import json 
import pandas as pd



response_API = requests.get('https://open.er-api.com/v6/latest/USD')
data = response_API.text
parse_json = json.loads(data)
exchange_rate = parse_json['rates']
ratelist = list(exchange_rate.items())

print(ratelist)

df = pd.DataFrame(ratelist, columns=['moeda','valor'])




#df_selecao = df[df["moeda"] == 'BRL']
df_selecao = df.query("moeda == 'BRL'")
print(df_selecao)
# Out:
# [('USD', 1), ('AED', 3.6725), ('AFN', 86.283018), ('ALL', 99.535922), ('AMD', 386.712432), ('ANG', 1.79), ('AOA', 612.783825), ('ARS', 243.015019), ('AUD', 1.490727), ('AWG', 1.79), ('AZN', 1.699711), ('BAM', 1.816089), ('BBD', 2), ('BDT', 107.954888), ('BGN', 1.816683), ('BHD', 0.376), ('BIF', 2815.437152), ('BMD', 1), ('BND', 1.34463), ('BOB', 6.920497), ('BRL', 4.923974), ('BSD', 1), ('BTN', 82.528712), ('BWP', 13.55812), ('BYN', 2.83164), ('BZD', 2), ('CAD', 1.335888), ('CDF', 2253.296756), ('CHF', 0.900573), ('CLP', 793.040973), ('CNY', 7.119816), ('COP', 4214.594839), ('CRC', 538.280731), ('CUP', 24), ('CVE', 102.386766), ('CZK', 21.968864), ('DJF', 177.721), ('DKK', 6.927349), ('DOP', 54.778889), ('DZD', 136.490866), ('EGP', 30.875388), ('ERN', 15), ('ETB', 54.706285), ('EUR', 0.928533), ('FJD', 2.231469), ('FKP', 0.798287), ('FOK', 6.927349), ('GBP', 0.797666), ('GEL', 2.609771), ('GGP', 0.798287), ('GHS', 11.510465), ('GIP', 0.798287), ('GMD', 62.457023), ('GNF', 8553.70584)
# ...

# %%
print(ratelist)
# Out:
# [('USD', 1), ('AED', 3.6725), ('AFN', 87.473356), ('ALL', 102.792352), ('AMD', 386.610842), ('ANG', 1.79), ('AOA', 576.791752), ('ARS', 237.985107), ('AUD', 1.533887), ('AWG', 1.79), ('AZN', 1.698358), ('BAM', 1.823156), ('BBD', 2), ('BDT', 107.773808), ('BGN', 1.822857), ('BHD', 0.376), ('BIF', 2809.99367), ('BMD', 1), ('BND', 1.351265), ('BOB', 6.916983), ('BRL', 5.012584), ('BSD', 1), ('BTN', 82.721331), ('BWP', 13.784018), ('BYN', 2.718774), ('BZD', 2), ('CAD', 1.359482), ('CDF', 2242.008265), ('CHF', 0.905374), ('CLP', 805.565694), ('CNY', 7.083392), ('COP', 4445.10511), ('CRC', 541.101711), ('CUP', 24), ('CVE', 102.785148), ('CZK', 22.078005), ('DJF', 177.721), ('DKK', 6.954303), ('DOP', 54.663436), ('DZD', 136.699812), ('EGP', 30.919943), ('ERN', 15), ('ETB', 54.696014), ('EUR', 0.932316), ('FJD', 2.24258), ('FKP', 0.805787), ('FOK', 6.954303), ('GBP', 0.805774), ('GEL', 2.592174), ('GGP', 0.805787), ('GHS', 11.538128), ('GIP', 0.805787), ('GMD', 59.04917), ('GNF', 8541.402024
# ...

# %%
import requests
from json import loads
import pandas as pd

url = "https://edgeapi.marchex.io/marketingedge/v5/api/groups"

payload = {}
headers = {
  'x-organization-token': 'EC0A9BB103E146CCAEE9899C982B8951',
  'subscription-key': '883b18cc3dc54f8cb102ed1088dd096f'
}

#response = requests.request("GET", url, headers=headers, data=payload)
response = requests.request("GET", url, headers=headers, data=payload).json()
#data = response.text
#parse_json = json.loads(data)

type(response)
#display(parse_json)
#print(response.text)

#exchange_rate = parse_json['rates']
#ratelist = list(exchange_rate.items())


#df = pd.DataFrame(response)

#df = pd.read_json(data)

#df_selecao = df[df["moeda"] == 'BRL']
#df_selecao = df.query("moeda == 'BRL'")
#print(df_selecao)

df = pd.DataFrame()
df = df.append(response, ignore_index=True)


contador = df.count()
display(contador)

#df = pd.DataFrame.from_dict(response, orient="index").reset_index()
# Out:
# C:\Users\SAP\AppData\Local\Temp\ipykernel_20804\3523048134.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(response, ignore_index=True)
# paging     1
# results    1
# dtype: int64

# %%
import requests

url = "https://api.five9.com/wssupervisor/v12/AdminWebService?wsdl&user=tlgjustin"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# <?xml version='1.0' encoding='UTF-8'?><wsdl:definitions xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns:wsdl="http://schemas.xmlsoap.org/wsdl/" xmlns:tns="http://service.supervisor.ws.five9.com/" xmlns:soap="http://schemas.xmlsoap.org/wsdl/soap/" xmlns:ns1="http://schemas.xmlsoap.org/soap/http" name="WsSupervisorService" targetNamespace="http://service.supervisor.ws.five9.com/">
#   <wsdl:types>
# <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:tns="http://service.supervisor.ws.five9.com/" attributeFormDefault="unqualified" elementFormDefault="unqualified" targetNamespace="http://service.supervisor.ws.five9.com/">
#   <xs:element name="acceptChatInvite" type="tns:acceptChatInvite"/>
#   <xs:element name="acceptChatInviteResponse" type="tns:acceptChatInviteResponse"/>
#   <xs:element name="closeChatSession" type="tns:closeChatSession"/>
#   <xs:element name="closeChatSessionResponse" type="tns:closeChatSessionResponse"/>
# ...

# %%
pip install zeep
# Out:
# ...
#      ---------------------------------------- 0.0/101.2 kB ? eta -:--:--
#      -------------------------------------- 101.2/101.2 kB 6.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#      ---------------------------------------- 54.5/54.5 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#      ---------------------------------------- 41.7/41.7 kB 2.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\SAP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import zeep

# set the WSDL URL
wsdl_url = "http://webservices.oorsprong.org/websamples.countryinfo/CountryInfoService.wso?WSDL"

# set method URL
method_url = "http://webservices.oorsprong.org/websamples.countryinfo/CountryIntPhoneCode"

# set service URL
service_url = "http://webservices.oorsprong.org/websamples.countryinfo/CountryInfoService.wso"

# create the header element
header = zeep.xsd.Element(
	"Header",
	zeep.xsd.ComplexType(
		[
			zeep.xsd.Element(
				"{http://www.w3.org/2005/08/addressing}Action", zeep.xsd.String()
			),
			zeep.xsd.Element(
				"{http://www.w3.org/2005/08/addressing}To", zeep.xsd.String()
			),
		]
	),
)
# set the header value from header element
header_value = header(Action=method_url, To=service_url)

# initialize zeep client
client = zeep.Client(wsdl=wsdl_url)

# set country code for India
country_code = "IN"

# make the service call
result = client.service.CountryIntPhoneCode(
	sCountryISOCode=country_code,
	_soapheaders=[header_value]
)
# print the result
print(f"Phone Code for {country_code} is {result}")

# set country code for United States
country_code = "US"

# make the service call
result = client.service.CountryIntPhoneCode(
	sCountryISOCode=country_code,
	_soapheaders=[header_value]
)

# print the result
print(f"Phone Code for {country_code} is {result}")



# set country code for United States
country_code = "BR"

# make the service call
result = client.service.CountryIntPhoneCode(
	sCountryISOCode=country_code,
	_soapheaders=[header_value]
)

# print the result
print(f"Phone Code for {country_code} is {result}")

print(response)
# Out:
# Phone Code for IN is 91
# Phone Code for US is 1
# Phone Code for BR is 55
# <Response [200]>
