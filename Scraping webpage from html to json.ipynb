# %%
import requests
import html_to_json
#pagina = 'https://www.facebook.com/ads/library/?active_status=all&ad_type=all&country=BR&q=course&sort_data[direction]=desc&sort_data[mode]=relevancy_monthly_grouped&search_type=keyword_unordered&media_type=all&content_languages[0]=pt'
#pagina = 'https://stlouissocomo.clothesmentor.com'
#pagina = 'https://takingcarababies.com'
pagina = "https://www.facebook.com/ads/library/?active_status=all&ad_type=all&country=BR&q=course&publisher_platforms[0]=facebook&search_type=keyword_unordered&media_type=all"
html_string = requests.get(pagina).content
#soup = BeautifulSoup(html, 'html.parser')

output_json = html_to_json.convert(html_string)
#print(output_json)
#f = open("c:/Saulo/exemplo.txt", "w")
#f.write(str(output_json))
#f.close()

#print(html_string)
# Out:
# {'_value': 'html', 'html': [{'_attributes': {'lang': 'pt', 'id': 'facebook', 'class': ['no_js']}, 'head': [{'meta': [{'_attributes': {'charset': 'utf-8'}}, {'_attributes': {'name': 'referrer', 'content': 'default', 'id': 'meta_referrer'}}, {'_attributes': {'name': 'viewport', 'content': 'width=device-width, initial-scale=1, minimum-scale=1 user-scalable=no'}}], 'script': [{'_attributes': {'nonce': 'h8eA7UZz'}, '_value': 'function envFlush(a){function b(b){for(var c in a)b[c]=a[c]}window.requireLazy?window.requireLazy(["Env"],b):(window.Env=window.Env||{},b(window.Env))}envFlush({"useTrustedTypes":false,"isTrustedTypesReportOnly":false,"ajaxpipe_token":"AXhmdZsBTC-vHjTO8-A","gk_instrument_object_url":true,"stack_trace_limit":30,"timesliceBufferSize":5000,"show_invariant_decoder":false,"compat_iframe_token":"AQ7dr0DKEmkFQYZIEtM","isCQuick":false});'}, {'_attributes': {'nonce': 'h8eA7UZz'}, '_value': '(function(a){function b(b){if(!window.openDatabase)return;b.I_AM_INCOGNITO_AND_I_REALLY_NEED_WEBSQL=function(a,b,c,d){return window.openDatabase(a,b,c,d)};window.openDatabase=function(){throw new Error()}}b(a)})(this);'}, {'_attributes': {'nonce': 'h8eA7UZz'}, '_value': '__DEV__=0;'}, {'_attributes': {'src': 'https://static.xx.fbcdn.net/rsrc.php/v3/yi/r/VKrSDizHqrG.js?_nc_x=Ij3Wp8lg5Kz', 'data-bootloader-hash': 'Fr0r2yk', 'nonce': 'h8eA7UZz'}}, {'_attributes': {'nonce': 'h8eA7UZz'}, '_value': 'requireLazy(["HasteSupportData"],function(m){m.handle({"clpData":{"1744178":{"r":1,"s":1},"1838142":{"r":1,"s":1},"1814852":{"r":1},"1949898":{"r":1},"1848815":{"r":10000,"s":1}},"gkxData":{"443":{"result":false,"hash":"AT4h1HaIxHYZn6IYqoY"},"1475":{"result":false,"hash":"AT7kEzfGQyTYdZJbf9s"},"1705":{"result":false,"hash":"AT45JGOqDPcAMbr3jDU"},"2755":{"result":true,"h